# %%
import numpy as np
import pandas as pd
from scipy.stats import norm,probplot
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
ssh = pd.read_csv('Seahawks.csv')
nep = pd.read_csv('Patriots.csv')

# %%
plt.figure()
plt.plot(ssh['W'],ssh['Pts Dif'],'*',color='blue', label='Seahawks')
plt.plot(nep['W'],nep['Pts Dif'],'*',color='gray', label='Patriots')
plt.xlabel('Wins')
plt.ylabel('Point Differential')
plt.legend()
plt.title('Wins Per Season vs Point Differential')
# Out:
# Text(0.5, 1.0, 'Wins Per Season vs Point Differential')

# %%
plt.figure()
plt.plot(ssh['L'],ssh['Pts Dif'],'*',color='blue', label='Seahawks')
plt.plot(nep['L'],nep['Pts Dif'],'*',color='gray', label='Patriots')
plt.xlabel('Losses')
plt.ylabel('Point Differential')
plt.legend()
plt.title('Losses Per Season Vs Point Differential')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Point Differential')

# %%
plt.figure()
plt.plot(ssh['L'],ssh['Off Pts Rk'],'*',color='blue', label='Seahawks')
plt.plot(nep['L'],nep['Off Pts Rk'],'*',color='gray', label='Patriots')
plt.xlabel('Losses')
plt.ylabel('Offensive Points Rank')
plt.legend()
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Offensive Points Rank')

# %%
plt.figure()
plt.plot(ssh['Off Pts Rk'],ssh['W'],'*',color='blue', label='Seahawks')
plt.plot(nep['Off Pts Rk'],nep['W'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Offensive Points Rank')
plt.legend()
plt.title('Wins Per Season Vs Offensive Points Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Points Rank')

# %%
plt.figure()
plt.plot(ssh['Pts Dif Rk'],ssh['W'],'*',color='blue', label='Seahawks')
plt.plot(nep['Pts Dif Rk'],nep['W'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Point Differential Rank')
plt.legend()
plt.title('Wins Per Season Vs Point Differential Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Point Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Pts Dif Rk'],ssh['L'],'*',color='blue', label='Seahawks')
plt.plot(nep['Pts Dif Rk'],nep['L'],'*',color='gray', label='Patriots')
plt.ylabel('Losses')
plt.xlabel('Point Differential Rank')
plt.legend()
plt.title('Losses Per Season Vs Point Differential Rank')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Point Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Yds Dif Rk'],ssh['L'],'*',color='blue', label='Seahawks')
plt.plot(nep['Yds Dif Rk'],nep['L'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Yard Differential Rank')
plt.legend()
plt.title('Losses Per Season Vs Yard Differential Rank')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Yard Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Yds Dif Rk'],ssh['W'],'*',color='blue', label='Seahawks')
plt.plot(nep['Yds Dif Rk'],nep['W'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Yard Differential Rank')
plt.legend()
plt.title('Wins Per Season Vs Yard Differential Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Yard Differential Rank')
