# %%
import numpy as np
import pandas as pd
from scipy.stats import norm,probplot
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
ssh = pd.read_csv('Seahawks.csv')
nep = pd.read_csv('Patriots.csv')
PS = pd.read_csv('Steelers.csv')
DL = pd.read_csv('Lions.csv')
GBP = pd.read_csv('Packers.csv')
CP = pd.read_csv('Panthers.csv')
LVR = pd.read_csv('Raiders.csv')
LAR = pd.read_csv('Rams.csv')
BR = pd.read_csv('Ravens.csv')
NOS = pd.read_csv('Saints.csv')
NYJ = pd.read_csv('Jets.csv')
JJ = pd.read_csv('Jaguars.csv')
SDC = pd.read_csv('San Diego.csv')
NYG = pd.read_csv('Giants.csv')
HT = pd.read_csv('Texans.csv')
TT = pd.read_csv('Titans.csv')
MV = pd.read_csv('Vikings.csv')
WF = pd.read_csv('Washington.csv')
MD = pd.read_csv('Dolphins.csv')
DC = pd.read_csv('Cowboys.csv')
IC = pd.read_csv('Colts.csv')
KCC = pd.read_csv('Chiefs.csv')
AC = pd.read_csv('Cardinals.csv')
TBB = pd.read_csv('Buccaneers.csv')
CB = pd.read_csv('Browns.csv')
PE = pd.read_csv('Eagles.csv')
BB = pd.read_csv('Bills.csv')
CB1 = pd.read_csv('Bengals.csv')
CB2 = pd.read_csv('Bears.csv')
SF49 = pd.read_csv('49ers.csv')
AF = pd.read_csv('Falcons.csv')
DB = pd.read_csv('Broncos.csv')
NFL = pd.read_csv('NFL.csv')

# %%
plt.figure()
plt.plot(ssh['W'],ssh['Pts Dif'],'*',color='blue', label='Seahawks')
plt.plot(nep['W'],nep['Pts Dif'],'*',color='gray', label='Patriots')
plt.xlabel('Wins')
plt.ylabel('Point Differential')
plt.legend()
plt.title('Wins Per Season vs Point Differential')
# Out:
# Text(0.5, 1.0, 'Wins Per Season vs Point Differential')

# %%
plt.figure()
plt.plot(ssh['L'],ssh['Pts Dif'],'*',color='blue', label='Seahawks')
plt.plot(nep['L'],nep['Pts Dif'],'*',color='gray', label='Patriots')
plt.xlabel('Losses')
plt.ylabel('Point Differential')
plt.legend()
plt.title('Losses Per Season Vs Point Differential')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Point Differential')

# %%
plt.figure()
plt.plot(ssh['L'],ssh['Off Pts Rk'],'*',color='blue', label='Seahawks')
plt.plot(nep['L'],nep['Off Pts Rk'],'*',color='gray', label='Patriots')
plt.xlabel('Losses')
plt.ylabel('Offensive Points Rank')
plt.legend()
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Offensive Points Rank')

# %%
plt.figure()
plt.plot(ssh['Off Pts Rk'],ssh['W'],'*',color='blue', label='Seahawks')
plt.plot(nep['Off Pts Rk'],nep['W'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Offensive Points Rank')
plt.legend()
plt.title('Wins Per Season Vs Offensive Points Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Points Rank')

# %%
plt.figure()
plt.plot(ssh['Pts Dif Rk'],ssh['W'],'*',color='blue', label='Seahawks')
plt.plot(nep['Pts Dif Rk'],nep['W'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Point Differential Rank')
plt.legend()
plt.title('Wins Per Season Vs Point Differential Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Point Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Pts Dif Rk'],ssh['L'],'*',color='blue', label='Seahawks')
plt.plot(nep['Pts Dif Rk'],nep['L'],'*',color='gray', label='Patriots')
plt.ylabel('Losses')
plt.xlabel('Point Differential Rank')
plt.legend()
plt.title('Losses Per Season Vs Point Differential Rank')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Point Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Yds Dif Rk'],ssh['L'],'*',color='blue', label='Seahawks')
plt.plot(nep['Yds Dif Rk'],nep['L'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Yard Differential Rank')
plt.legend()
plt.title('Losses Per Season Vs Yard Differential Rank')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Yard Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Yds Dif Rk'],ssh['W'],'*',color='blue', label='Seahawks')
plt.plot(nep['Yds Dif Rk'],nep['W'],'*',color='gray', label='Patriots')
plt.ylabel('Wins')
plt.xlabel('Yard Differential Rank')
plt.legend()
plt.title('Wins Per Season Vs Yard Differential Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Yard Differential Rank')

# %%
plt.figure()
plt.plot(ssh['Off Pts Rk'],ssh['W'],'*')
plt.plot(nep['Off Pts Rk'],nep['W'],'*')
plt.plot(PS['Off Pts Rk'],PS['W'],'*')
plt.plot(DL['Off Pts Rk'],DL['W'],'*')
plt.plot(GBP['Off Pts Rk'],GBP['W'],'*')
plt.plot(CP['Off Pts Rk'],CP['W'],'*')
plt.plot(LVR['Off Pts Rk'],LVR['W'],'*')
plt.plot(LAR['Off Pts Rk'],LAR['W'],'*')
plt.plot(BR['Off Pts Rk'],BR['W'],'*')
plt.plot(NOS['Off Pts Rk'],NOS['W'],'*')
plt.plot(NYJ['Off Pts Rk'],NYJ['W'],'*')
plt.plot(JJ['Off Pts Rk'],JJ['W'],'*')
plt.plot(SDC['Off Pts Rk'],SDC['W'],'*')
plt.plot(NYG['Off Pts Rk'],NYG['W'],'*')
plt.plot(HT['Off Pts Rk'],HT['W'],'*')
plt.plot(TT['Off Pts Rk'],TT['W'],'*')
plt.plot(MV['Off Pts Rk'],MV['W'],'*')
plt.plot(WF['Off Pts Rk'],WF['W'],'*')
plt.plot(MD['Off Pts Rk'],MD['W'],'*')
plt.plot(DC['Off Pts Rk'],DC['W'],'*')
plt.plot(IC['Off Pts Rk'],IC['W'],'*')
plt.plot(KCC['Off Pts Rk'],KCC['W'],'*')
plt.plot(AC['Off Pts Rk'],AC['W'],'*')
plt.plot(TBB['Off Pts Rk'],TBB['W'],'*')
plt.plot(CB['Off Pts Rk'],CB['W'],'*')
plt.plot(PE['Off Pts Rk'],PE['W'],'*')
plt.plot(BB['Off Pts Rk'],BB['W'],'*')
plt.plot(CB1['Off Pts Rk'],CB1['W'],'*')
plt.plot(CB2['Off Pts Rk'],CB2['W'],'*')
plt.plot(SF49['Off Pts Rk'],SF49['W'],'*')
plt.ylabel('Wins')
plt.xlabel('Off Points Rank')
plt.title('Wins Per Season Vs Offensive Points Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Points Rank')

# %%
plt.figure()
plt.plot(ssh['Off Yds Rk'],ssh['W'],'*',color = 'black')
plt.plot(nep['Off Yds Rk'],nep['W'],'*',color = 'black')
plt.plot(PS['Off Yds Rk'],PS['W'],'*',color = 'black')
plt.plot(DL['Off Yds Rk'],DL['W'],'*',color = 'black')
plt.plot(GBP['Off Yds Rk'],GBP['W'],'*',color = 'black')
plt.plot(CP['Off Yds Rk'],CP['W'],'*',color = 'black')
plt.plot(LVR['Off Yds Rk'],LVR['W'],'*',color = 'black')
plt.plot(LAR['Off Yds Rk'],LAR['W'],'*',color = 'black')
plt.plot(BR['Off Yds Rk'],BR['W'],'*',color = 'black')
plt.plot(NOS['Off Yds Rk'],NOS['W'],'*',color = 'black')
plt.plot(NYJ['Off Yds Rk'],NYJ['W'],'*',color = 'black')
plt.plot(JJ['Off Yds Rk'],JJ['W'],'*',color = 'black')
plt.plot(SDC['Off Yds Rk'],SDC['W'],'*',color = 'black')
plt.plot(NYG['Off Yds Rk'],NYG['W'],'*',color = 'black')
plt.plot(HT['Off Yds Rk'],HT['W'],'*',color = 'black')
plt.plot(TT['Off Yds Rk'],TT['W'],'*',color = 'black')
plt.plot(MV['Off Yds Rk'],MV['W'],'*',color = 'black')
plt.plot(WF['Off Yds Rk'],WF['W'],'*',color = 'black')
plt.plot(MD['Off Yds Rk'],MD['W'],'*',color = 'black')
plt.plot(DC['Off Yds Rk'],DC['W'],'*',color = 'black')
plt.plot(IC['Off Yds Rk'],IC['W'],'*',color = 'black')
plt.plot(KCC['Off Yds Rk'],KCC['W'],'*',color = 'black')
plt.plot(AC['Off Yds Rk'],AC['W'],'*',color = 'black')
plt.plot(TBB['Off Yds Rk'],TBB['W'],'*',color = 'black')
plt.plot(CB['Off Yds Rk'],CB['W'],'*',color = 'black')
plt.plot(PE['Off Yds Rk'],PE['W'],'*',color = 'black')
plt.plot(BB['Off Yds Rk'],BB['W'],'*',color = 'black')
plt.plot(CB1['Off Yds Rk'],CB1['W'],'*',color = 'black')
plt.plot(CB2['Off Yds Rk'],CB2['W'],'*',color = 'black')
plt.plot(SF49['Off Yds Rk'],SF49['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Off Yards Rank')
plt.title('Wins Per Season Vs Offensive Yards Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Yards Rank')

# %%
plt.figure()
plt.plot(NFL['Off Yds Rk'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Off Yards Rank')
plt.title('Wins Per Season Vs Offensive Yards Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Yards Rank')

# %%
plt.figure()
plt.plot(NFL['Off Yds Rk'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Off Yards Rank')
plt.title('Losses vs Offensive Yard Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Yards Rank')

# %%
plt.figure()
plt.plot(NFL['Off Pts Rk'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Off Points Rank')
plt.title('Losses vs Offensive Points Rank')
# Out:
# Text(0.5, 1.0, 'Losses vs Offensive Points Rank')

# %%
plt.figure()
plt.plot(NFL['Pts S'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Points Scored')
plt.title('Wins Per Season Vs Offensive Yards Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Points Scored')

# %%
plt.figure()
plt.plot(NFL['Pts S'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Points Scored')
plt.title('Losses Per Season Vs Points Scored')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Points Scored')

# %%
plt.figure()
plt.plot(NFL['OSRS'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Offensive Simple Rating System Score')
plt.title('Wins Per Season Vs Offensive Simple Rating System Score')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Offensive Simple Rating System Score')

# %%
plt.figure()
plt.plot(NFL['OSRS'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Offensive Simple Rating System Score')
plt.title('Losses Per Season Vs Offensive Simple Rating System Score')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Offensive Simple Rating System Score')

# %%
plt.figure()
plt.plot(NFL['DSRS'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Defensive Simple Rating System Score')
plt.title('Wins Per Season Vs Defensive Simple Rating System Score')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Defensive Simple Rating System Score')

# %%
plt.figure()
plt.plot(NFL['DSRS'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Defensive Simple Rating System Score')
plt.title('Losses Per Season Vs Defensive Simple Rating System Score')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Defensive Simple Rating System Score')

# %%
plt.figure()
plt.plot(NFL['SRS'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Simple Rating System Score')
plt.title('Wins Per Season Vs Simple Rating System Score')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Simple Rating System Score')

# %%
plt.figure()
plt.plot(NFL['SRS'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Simple Rating System Score')
plt.title('Losses Per Season Vs Simple Rating System Score')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Simple Rating System Score')

# %%
plt.figure()
plt.plot(NFL['SoS'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Strength of Schedule Score')
plt.title('Wins Per Season Vs Strength of Schedule Score')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Strength of Schedule Score')

# %%
plt.figure()
plt.plot(NFL['SoS'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Strength of Schedule Score')
plt.title('Losses Per Season Vs Strength of Schedule Score')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Strength of Schedule Score')

# %%
plt.figure()
plt.plot(NFL['Pts Dif Rk'],NFL['L'],'*',color='blue')
plt.ylabel('Losses')
plt.xlabel('Point Differential Rank')
plt.title('Losses Per Season Vs Point Differential Rank')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Point Differential Rank')

# %%
plt.figure()
plt.plot(NFL['Pts Dif Rk'],NFL['W'],'*',color='blue')
plt.ylabel('Wins')
plt.xlabel('Point Differential Rank')
plt.title('Wins Per Season Vs Point Differential Rank')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Point Differential Rank')

# %%
plt.figure()
plt.plot(NFL['Pts Dif'],NFL['W'],'*',color='blue')
plt.ylabel('Wins')
plt.xlabel('Point Differential')
plt.title('Wins Per Season Vs Point Differential')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Point Differential')

# %%
plt.figure()
plt.plot(NFL['Pts Dif'],NFL['L'],'*',color='blue')
plt.ylabel('Losses')
plt.xlabel('Point Differential')
plt.title('Losses Per Season Vs Point Differential')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Point Differential')

# %%
plt.figure()
plt.plot(NFL['Pts A'],NFL['L'],'*',color = 'black')
plt.ylabel('Losses')
plt.xlabel('Points Scored')
plt.title('Losses Per Season Vs Points Scored by Opposition')
# Out:
# Text(0.5, 1.0, 'Losses Per Season Vs Points Scored by Opposition')

# %%
plt.figure()
plt.plot(NFL['Pts A'],NFL['W'],'*',color = 'black')
plt.ylabel('Wins')
plt.xlabel('Points Scored')
plt.title('Wins Per Season Vs Points Scored by Opposition')
# Out:
# Text(0.5, 1.0, 'Wins Per Season Vs Points Scored by Opposition')

# %%
ls = LinearRegression()

# %%
X = np.array(NFL['Pts Dif']).reshape(-1,1)
Y = np.array(NFL['W']).reshape(-1,1)

# %%
ls.fit(X,Y)
# Out:
# LinearRegression()

# %%
ls.intercept_
# Out:
# array([7.91124037])

# %%
ls.coef_
# Out:
# array([[0.02811294]])

# %%
yhat = ls.predict(X)

# %%
plt.figure()
plt.plot(NFL['Pts Dif'],NFL['W'],'*',color='Blue')
plt.plot(X,yhat,color='Purple')

# %%
residuals = Y-yhat

# %%
probplot(residuals.T[0], plot=plt)
# Out:
# ((array([-3.16966014e+00, -2.90228969e+00, -2.75294310e+00, -2.64754010e+00,
#          -2.56526402e+00, -2.49737971e+00, -2.43936133e+00, -2.38855000e+00,
#          -2.34324618e+00, -2.30229533e+00, -2.26487615e+00, -2.23038282e+00,
#          -2.19835529e+00, -2.16843566e+00, -2.14033983e+00, -2.11383841e+00,
#          -2.08874338e+00, -2.06489868e+00, -2.04217328e+00, -2.02045606e+00,
#          -1.99965193e+00, -1.97967891e+00, -1.96046574e+00, -1.94195014e+00,
#          -1.92407730e+00, -1.90679876e+00, -1.89007141e+00, -1.87385677e+00,
#          -1.85812034e+00, -1.84283103e+00, -1.82796075e+00, -1.81348402e+00,
#          -1.79937767e+00, -1.78562055e+00, -1.77219330e+00, -1.75907816e+00,
#          -1.74625880e+00, -1.73372015e+00, -1.72144829e+00, -1.70943033e+00,
#          -1.69765432e+00, -1.68610913e+00, -1.67478440e+00, -1.66367048e+00,
#          -1.65275834e+00, -1.64203952e+00, -1.63150611e+00, -1.62115066e+00,
# ...

# %%
plt.scatter(residuals,yhat)
